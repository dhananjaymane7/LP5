# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Boston.csv")
print(df.head(10))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV  CAT. MEDV  Unnamed: 15  Unnamed: 16
# 0  396.90   4.98  24.0          0          NaN          NaN
# 1  396.90   9.14  21.6          0          NaN          NaN
# 2  392.83   4.03  34.7          1          NaN          NaN
# 3  394.63   2.94  33.4          1          NaN          NaN
# 4  396.90   5.33  36.2          1          NaN          NaN
# 5  394.12   5.21  28.7          0          NaN          NaN
# 6  395.60  12.43  22.9          0          NaN          NaN
# 7  396.90  19.15  27.1          0          NaN          NaN
# 8  386.63  29.93  16.5          0          NaN          NaN
# 9  386.71  17.10  18.9          0          NaN          NaN

# %%
df.drop(columns=['Unnamed: 15',"Unnamed: 16",'CAT. MEDV'], inplace=True)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
from scipy.stats import zscore
import numpy as np

# %%
original_df = df.copy()

# %%
zscores = np.abs(zscore(df))
df = df[(zscores < 3).all(axis=1)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot before and after for one feature, e.g., LSTAT
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(y='LSTAT', data=original_df, ax=axes[0])
axes[0].set_title('Before Removing Outliers')
sns.boxplot(y='LSTAT', data=df, ax=axes[1])
axes[1].set_title('After Removing Outliers')
plt.tight_layout()
plt.show()

# %%
cor = df.corr()
cor.loc['MEDV']
# Out:
# CRIM      -0.418531
# ZN         0.306172
# INDUS     -0.486369
# CHAS            NaN
# NOX       -0.417222
# RM         0.734041
# AGE       -0.384446
# DIS        0.234420
# RAD       -0.347297
# TAX       -0.453723
# PTRATIO   -0.476781
# B          0.234161
# LSTAT     -0.738700
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
import seaborn as sns
sns.heatmap(cor, annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = df.loc[:,['LSTAT','PTRATIO','RM']]
Y = df.loc[:,'MEDV']
X.shape, Y.shape
# Out:
# ((415, 3), (415,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(X,Y,test_size=0.25,random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(128,input_shape =(3,),activation='linear',name='input'))
model.add(Dense(64,activation='linear',name='layer1'))
model.add(Dense(128,activation='linear',name='layer2'))
model.add(Dense(128,activation='linear',name='layer3'))
model.add(Dense(64,activation='linear',name='layer4'))
model.add(Dense(64,activation='linear',name='layer5'))
model.add(Dense(32,activation='linear',name='layer6'))
model.add(Dense(32,activation='linear',name='layer7'))
model.add(Dense(16,activation='linear',name='layer8'))
model.add(Dense(16,activation='linear',name='layer9'))
model.add(Dense(8,activation='linear',name='layer10'))
model.add(Dense(8,activation='linear',name='layer11'))
model.add(Dense(4,activation='linear',name='layer12'))
model.add(Dense(1,activation='linear',name='output'))
model.compile(optimizer='adam',loss='mse',metrics=['mae'])
# Out:
# C:\Users\yashd\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x_train,y_train,epochs=40,validation_split=0.05)
# Out:
# Epoch 1/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 509.4821 - mae: 21.5180 - val_loss: 386.3939 - val_mae: 18.4113
# Epoch 2/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 292.9569 - mae: 15.4960 - val_loss: 53.5472 - val_mae: 6.0854
# Epoch 3/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.3257 - mae: 6.3509 - val_loss: 25.6335 - val_mae: 3.9768
# Epoch 4/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.7623 - mae: 4.6705 - val_loss: 20.5163 - val_mae: 3.2670
# Epoch 5/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.5746 - mae: 4.1475 - val_loss: 15.0152 - val_mae: 3.0531
# Epoch 6/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.1526 - mae: 3.6766 - val_loss: 7.4806 - val_mae: 2.3837
# Epoch 7/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.1541 - mae: 3.3810 - val_loss: 13.4901 - val_mae: 2.4088
# Epoch 8/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.4859 - mae: 3.2250 - val_loss: 12.2215 - val_mae: 2.7657
# Epoch 9/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.3346 - mae: 3.3226 - val_loss: 11.2347 - val_mae: 2.6373
# Epoch 10/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.0110 - mae: 3.5477 - val_loss: 11.9698 - val_mae: 2.8032
# Epoch 11/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.6227 - mae: 3.6178 - val_loss: 10.2964 - val_mae: 2.3838
# Epoch 12/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.5667 - mae: 3.1411 - val_loss: 10.8397 - val_mae: 2.5512
# Epoch 13/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.7824 - mae: 3.3941 - val_loss: 15.6186 - val_mae: 3.1243
# Epoch 14/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7965 - mae: 3.3360 - val_loss: 18.7301 - val_mae: 3.5525
# Epoch 15/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.3520 - mae: 3.4140 - val_loss: 11.8259 - val_mae: 2.7883
# Epoch 16/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7401 - mae: 3.4524 - val_loss: 13.5740 - val_mae: 2.5742
# Epoch 17/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.5014 - mae: 3.4147 - val_loss: 12.0115 - val_mae: 2.8626
# Epoch 18/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.6710 - mae: 3.3355 - val_loss: 10.4650 - val_mae: 2.3588
# Epoch 19/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.6429 - mae: 3.2791 - val_loss: 12.9930 - val_mae: 2.8093
# Epoch 20/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.7156 - mae: 3.2977 - val_loss: 11.8083 - val_mae: 2.7755
# Epoch 21/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.9601 - mae: 3.0558 - val_loss: 15.9231 - val_mae: 3.0799
# Epoch 22/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.5144 - mae: 3.5336 - val_loss: 13.6187 - val_mae: 2.8850
# Epoch 23/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.3370 - mae: 3.0750 - val_loss: 9.2806 - val_mae: 2.4899
# Epoch 24/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.5808 - mae: 3.3629 - val_loss: 11.0964 - val_mae: 2.5700
# Epoch 25/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.0039 - mae: 3.4588 - val_loss: 11.1566 - val_mae: 2.6521
# Epoch 26/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.2564 - mae: 3.4572 - val_loss: 11.1150 - val_mae: 2.6841
# Epoch 27/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.0622 - mae: 3.2006 - val_loss: 8.8535 - val_mae: 2.4975
# Epoch 28/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.1577 - mae: 3.4033 - val_loss: 11.8850 - val_mae: 2.6860
# Epoch 29/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.3162 - mae: 3.9816 - val_loss: 11.8341 - val_mae: 2.4777
# Epoch 30/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.5349 - mae: 3.7946 - val_loss: 13.9002 - val_mae: 2.4973
# Epoch 31/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.4100 - mae: 3.1792 - val_loss: 9.4927 - val_mae: 2.5505
# Epoch 32/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.8535 - mae: 3.3221 - val_loss: 10.0757 - val_mae: 2.4669
# Epoch 33/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.9596 - mae: 3.1361 - val_loss: 10.3826 - val_mae: 2.4933
# Epoch 34/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.8081 - mae: 3.5909 - val_loss: 18.1895 - val_mae: 2.6520
# Epoch 35/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.4390 - mae: 3.6726 - val_loss: 12.2684 - val_mae: 2.4648
# Epoch 36/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.3941 - mae: 3.2053 - val_loss: 11.2063 - val_mae: 2.5626
# Epoch 37/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.1121 - mae: 3.1293 - val_loss: 11.9415 - val_mae: 2.7238
# Epoch 38/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6540 - mae: 3.1816 - val_loss: 9.3558 - val_mae: 2.4762
# Epoch 39/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.2225 - mae: 3.0412 - val_loss: 9.9215 - val_mae: 2.5182
# Epoch 40/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.6679 - mae: 3.1009 - val_loss: 11.3991 - val_mae: 2.5274

# %%
output = model.evaluate(x_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.0360 - mae: 3.1765

# %%
y_pred = model.predict(x=x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Assuming y_test and y_pred are already defined
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 18.71
# Mean Absolute Error (MAE): 2.95
# R² Score: 0.68

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,y_pred, color='blue', label = 'Predicted vs Actual', alpha=0.6)
plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)], color='red', label='Ideal Prediction (y=x)')

# Adding labels and title
plt.title('Comparison of Predicted and Actual Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

# Show the plot
plt.show()
